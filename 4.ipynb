# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Илья, привет!</b> Мы рады тебя видеть на территории код-ревьюеров. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У тебя неограниченное количество попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <div class="alert alert-info"> 🧩<b>Комментарии студента:</b> Привет, Александр! Спасибо большое за твоё ревью, постарался исправить замечания :) </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Илья, рад тебя видеть) Спасибо за правки, давай посмотрим =)
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Пример можно посмотреть в самом первом проекте (Музыка городов)
# </div>

# %% [markdown]
# **Цель исследования**
# Проанализировать данные для определения зависимости цен на недвижимость в Санкт-Петербурге и соседних насёленных пунктах за несколько лет
#
# **Ход исследования**
#
# Данные о поведении пользователей получаем из данных предоставленных сервисом Яндекс.Недвижимость. О качестве данных ничего не известно. Поэтому перед проверкой гипотез понадобится обзор данных.
#
# Необходимо проверить данные на ошибки, найти аномальные значения и оценить их влияние на исследование. Затем, на этапе предобработки сделать все возможное, чтобы исправить самые критичные ошибки данных.
#
# Таким образом, исследование пройдёт в четыере этапа:
#  1. Обзор данных.
#  2. Предобработка данных.
#  3. Определение зависимости факторов друг от друга.
#  4. Визуализация данных в виде различных графиков.

# %% [markdown]
# <div class="alert alert-info"> 🧩<b>Комментарии студента:</b> добавил) </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn 
data = pd.read_csv('/datasets/real_estate_data.csv', sep ='\t')
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %% [markdown]
# ### Предобработка данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.hist(figsize=(15, 20))
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
# Такие предупреждения можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку matplotlib
# 2. В конец кода добавить `;`
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div class="alert alert-info"> 🧩<b>Комментарии студента:</b> Спасибо! Стало немного удобнее изучать данные </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Рад помочь ^^
# </div>

# %% [markdown]
# **2.1  Удаление пропусков**

# %% [markdown]
# 1. Приступаем к изучению пропущенных значений в данных

# %%
print(data.isna().sum().sort_values(ascending=False))
# Out:
# is_apartment            20924
# parks_nearest           15620
# ponds_nearest           14589
# balcony                 11519
# ceiling_height           9195
# airports_nearest         5542
# cityCenters_nearest      5519
# ponds_around3000         5518
# parks_around3000         5518
# days_exposition          3181
# kitchen_area             2278
# living_area              1903
# floors_total               86
# locality_name              49
# total_images                0
# last_price                  0
# studio                      0
# floor                       0
# rooms                       0
# first_day_exposition        0
# total_area                  0
# open_plan                   0
# dtype: int64

# %%
pd.DataFrame(round(data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_e2354_row0_col0,#T_e2354_row1_col0,#T_e2354_row2_col0,#T_e2354_row3_col0,#T_e2354_row4_col0,#T_e2354_row6_col0,#T_e2354_row8_col0,#T_e2354_row10_col0,#T_e2354_row11_col0,#T_e2354_row14_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_e2354_row5_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_e2354_row7_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_e2354_row9_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e2354_row12_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_e2354_row13_col0{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_e2354_row15_col0,#T_e2354_row16_col0,#T_e2354_row17_col0,#T_e2354_row19_col0{
#             background-color:  #90b2fe;
#             color:  #000000;
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверить колличество пропусков в % можно вот так:
#
#
#     pd.DataFrame(round(df.isna().mean()*100,)).style.background_gradient('coolwarm')

# %%
#is_apartment            20924 п.3 главы 2.1 Удаление пропусков
#parks_nearest           15620 п.2 главы 2.1 Удаление пропусков - оставляем NaN
#ponds_nearest           14589 п.2 главы 2.1 Удаление пропусков - оставляем NaN
#balcony                 11519 п.4 главы 2.1 Удаление пропусков
#ceiling_height           9195 п.5 главы 2.1 Удаление пропусков
#airports_nearest         5542 п.2 главы 2.1 Удаление пропусков - оставляем NaN
#cityCenters_nearest      5519 п.2 главы 2.1 Удаление пропусков - оставляем NaN
#ponds_around3000         5518 п.6 главы 2.1 Удаление пропусков
#parks_around3000         5518 п.6 главы 2.1 Удаление пропусков
#days_exposition          3181 п.7 главы 2.1 Удаление пропусков
#kitchen_area             2278 п.8 главы 2.1 Удаление пропусков
#living_area              1903 п.9 главы 2.1 Удаление пропусков
#floors_total               86 п.10 главы 2.1 Удаление пропусков
#locality_name              49 п.11 главы 2.1 Удаление пропусков

# %% [markdown]
# 2. Пропуски в некоторых столбцах, такие как parks_nearest, ponds_nearest, cityCenters_nearest без сторонней информации мы заполнить не сможем, т.к., скорее всего, это поля, полученные автоматически при помощи карты или некоторые ошибки при выгрузке данных.

# %% [markdown]
# Также проверим данные на наличие явных дубликатов

# %%
data.duplicated().sum()
#с первого взгляда кажется, что дубликатов нет, убедимся в этом позже, разобравшись с пропусками
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверка на дубликаты - основа предобработки данных

# %% [markdown]
# 3. Предположим, что если пользователь не указал, что жилая площадь является "Аппартаментами" она ей не является и заменим пропущенные значения на "нет"
# заменяем пропущенные значения на 0.

# %%
data['is_apartment'] = data['is_apartment'].fillna(value = 'False')

# %% [markdown]
# 4. В столбце "balcony" должна быть указано кол-во балконов в квартире, в случае если данные не заполненны можно предроложить, что балкона - нет, т.е. приравнием к 0
# заменяем пропущенные значения на 0. Приводим в целочисленный тип количество балконов.

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен

# %% [markdown]
# 5. Сегодня минимальной нормой в России считается высота потолка 2,4 метра. Поэтому заполним значения данные данной величиной

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(2.4)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Некоторые столбцы можно поменять на значения, относительно своего района (например высота пололков). Вот так
#
#
# ![image.png](attachment:image.png)
#
# Если хочешь - дарю свой код =)
# </div>

# %% [markdown]
# <div class="alert alert-info"> 🧩<b>Комментарии студента:</b> Спасибо! Когда заполнял это значение думал сделать отдельные вычисления для центра Санкт-Петербурга, потому что как правило там потолки выше
# но решил остановиться на установке минимума для всех
#
# Правильно вообще заполнять предполагаемым минимумом или лучше обращаться к медианным значениям?</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# В данном случае, чем ближе к истине, чем лучше) В высоте потолков, в принципе, можно и обычной медианой
# </div>

# %% [markdown]
# 6.Данные по количеству парков и прудов поблизости получены автоматически, если значение не указано, предположим, что их в пределах 3000м нет.

# %%
data['ponds_around3000'] = data['ponds_around3000'].fillna(0)
data['parks_around3000'] = data['parks_around3000'].fillna(0)

# %% [markdown]
# 7. Узнать как долго выставлено обьявление невозможно, поэтому заполним пропуски 0, предположив, что обьявление только выставлено

# %%
#print(data['first_day_exposition'].max())
data['days_exposition'] = data['days_exposition'].fillna(0)

# %% [markdown]
# 8. Значения kitchen_area узнать не получится, поэтому заполним медианными значениями

# %%
grouped_kitchen_area = data.groupby('rooms')['kitchen_area'].median()
for value in grouped_kitchen_area.index:
    data.loc[(data['rooms'] == value) & (data['kitchen_area'].isna()), 'kitchen_area'] = grouped_kitchen_area[value]

# %% [markdown]
# 9. Аналогично сделаем с living_area

# %%
#print(data['rooms'].unique())
#Отсутсвие комнат выглядит как ошибка в данных, поэтому удалим из датасета строки с такими значениями
data = data.loc[data['rooms'] != 0]

#Заменяем пропущенные значения  в living_area на медианное значение группы (группа по комнатам).
grouped_room_number = data.groupby('rooms')['living_area'].median()

for value in grouped_room_number.index:
    data.loc[(data['rooms'] == value) & (data['living_area'].isna()), 'living_area'] = grouped_room_number[value]

# %% [markdown]
# 10. Если количество этажей не указано, предположим, что это самый высокий этаж

# %%
data['floors_total'] = data['floors_total'].fillna(data['floor'])

# %% [markdown]
# Незаполненных данных в locality_name всего 49, возможно их стоит удалить, т.к расположение квартиры может серьезно влиять на цену, но пока что оставим пустые значения

# %%
data = data.dropna(subset=['locality_name'])

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верно. Если пропусков меньше 5-8% их лучше сразу удалить, дабы сэкономить время
# </div>

# %% [markdown]
# Проверка

# %%
print(data.isna().sum().sort_values(ascending=False))
# Out:
# parks_nearest           15418
# ponds_nearest           14437
# airports_nearest         5455
# cityCenters_nearest      5432
# total_images                0
# last_price                  0
# ponds_around3000            0
# parks_around3000            0
# locality_name               0
# balcony                     0
# kitchen_area                0
# open_plan                   0
# studio                      0
# is_apartment                0
# floor                       0
# living_area                 0
# floors_total                0
# ceiling_height              0
# rooms                       0
# first_day_exposition        0
# total_area                  0
# days_exposition             0
# dtype: int64

# %% [markdown]
# **2.2. Предобработка типов данных**

# %% [markdown]
# Заменяем вещественный тип данных на целочисленный, во всех количественных столбцах для удобства просмотра и дальнейшей работы

# %%
data['total_images'] = data['total_images'].astype('int')
data['rooms'] = data['rooms'].astype('int')
data['floor'] = data['floor'].astype('int')
data['balcony'] = data['balcony'].astype('int')
data['floors_total'] = data['floors_total'].astype('int')
data['days_exposition'] = data['days_exposition'].astype('int')
data['parks_around3000'] = data['parks_around3000'].astype('int')
data['ponds_around3000'] = data['ponds_around3000'].astype('int')
data['last_price'] = data['last_price'].astype('int')

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%d')

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Давай посмотрим на столбец `last_price`, он имеет дробный тип данных. Но ведь никто не продаёт недвижку с копейками. Что думаешь?
# </div>

# %% [markdown]
# <div class="alert alert-info"> 🧩<b>Комментарии студента:</b> На самом деле я пытался, но программа выдавала ошибку  "Cannot convert non-finite values (NA or inf) to integer", хотя пропущенных значений там нет, на удивление сейчас все заработало...   </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Немного шаманства с бубном, и всё работает =)
# </div>

# %% [markdown]
# **2.3 Обработка дубликатов**

# %% [markdown]
# Вообще очень тут очень сложно получить точные результаты.
# [в одной только России 4 Москвы](http://gototrip.com/publications/goroda-s-odinakovymi-nazvaniyami-v-mire#:~:text=%D0%92%20%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B8%20%E2%80%93%20%D1%86%D0%B5%D0%BB%D1%8B%D1%85%20%D1%87%D0%B5%D1%82%D1%8B%D1%80%D0%B5%20%D0%9C%D0%BE%D1%81%D0%BA%D0%B2%D1%8B,%D1%8D%D1%82%D0%BE%20%D0%BF%D1%80%D0%B8%D0%B3%D0%BE%D1%80%D0%BE%D0%B4%D0%BD%D1%8B%D0%B9%20%D1%80%D0%B0%D0%B9%D0%BE%D0%BD%20%D0%B3%D0%BE%D1%80%D0%BE%D0%B4%D0%B0%20%D0%93%D0%B5%D0%BD%D1%82%D0%B0), есть одноименные поселки в разных регионах страны
#
# предположим, что пользователи запутались в типах поселков

# %%
#print(data['locality_name'].unique())

# %%
data['locality_name'] = data['locality_name'].str.replace('ё','е')
data['locality_name'] = data['locality_name'].str.replace('поселок городского типа','поселок')
data['locality_name'] = data['locality_name'].str.replace('коттеджный поселок','поселок')
data['locality_name'] = data['locality_name'].str.replace('городской поселок','поселок')
data['locality_name'] = data['locality_name'].str.replace('поселок станции', 'поселок')
data['locality_name'] = data['locality_name'].str.replace('поселок при железнодорожной станции', 'поселок')
print(data['locality_name'].unique())
# Out:
# ['Санкт-Петербург' 'поселок Шушары' 'поселок Янино-1' 'поселок Парголово'
#  'поселок Мурино' 'Ломоносов' 'Сертолово' 'Петергоф' 'Пушкин'
#  'деревня Кудрово' 'Коммунар' 'Колпино' 'поселок Красный Бор' 'Гатчина'
#  'деревня Федоровское' 'Выборг' 'Кронштадт' 'Кировск'
#  'деревня Новое Девяткино' 'поселок Металлострой' 'поселок Лебяжье'
#  'поселок Сиверский' 'поселок Молодцово' 'поселок Кузьмоловский'
#  'садовое товарищество Новая Ропша' 'Павловск' 'деревня Пикколово'
#  'Всеволожск' 'Волхов' 'Кингисепп' 'Приозерск' 'Сестрорецк'
#  'деревня Куттузи' 'поселок Аннино' 'поселок Ефимовский'
#  'поселок Плодовое' 'деревня Заклинье' 'поселок Торковичи'
#  'поселок Первомайское' 'Красное Село' 'поселок Понтонный' 'Сясьстрой'
#  'деревня Старая' 'деревня Лесколово' 'поселок Новый Свет' 'Сланцы'
#  'село Путилово' 'Ивангород' 'Мурино' 'Шлиссельбург' 'Никольское'
#  'Зеленогорск' 'Сосновый Бор' 'деревня Оржицы' 'деревня Кальтино'
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Отличный код
# </div>

# %%
print(data.duplicated().sum()) # Считаем сколько явных дубликатов
# Out:
# 0

# %%
data = data.drop_duplicates() # Удаляем явные дубликаты

# %% [markdown]
# 2.4 Удаление аномальных значений

# %% [markdown]
# Из гистограмм видно,что у нас выбиваются значения в гистограммах по столбацам total_area,rooms,floors_total,living_area, kitchen_area, days_exposition

# %% [markdown]
# Рассмотрим 'total_area'

# %%
#Теперь пройдемся отдельно по каждому столбцу. Сначала построим гисторгамму для total_area

# %%
data['total_area'].hist(bins = 100)
plt.show()

# %%
#Можно исключить слишком большие значения общей площади и посмoтреть на остальные.
 
#используя параметр range, изучим распределение общей площади в диапазоне 0 до 400
 
data['total_area'].hist(bins = 100, range=(0,400))
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет: Рекомендую не удалять данные "на глаз". Лучше посмотреть на выбросы и аномалии данных математически, и удалить их. В этом поможет метод boxplot()
# </div>

# %%
#получим характеристики по выборке методом describe()
 
data['total_area'].describe()
# Out:
# count    23453.000000
# mean        60.589877
# std         35.618736
# min         12.000000
# 25%         40.110000
# 50%         52.000000
# 75%         70.000000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Общая площадь в нашей выборке колеблется от 12 до 900 м2, среднее значение 60,35 кв.м, а медиана 52 кв.м. Распределение данных Гаусса. Будем считать аномальными значения более 300 кв.м

# %% [markdown]
# Рассмотрим 'living_area'

# %%
data['living_area'].hist(bins = 100, range=(0,300))
plt.show()

# %%
#получим характеристики по выборке методом describe()
 
data['living_area'].describe()
# Out:
# count    23453.000000
# mean        34.443397
# std         21.745004
# min          2.000000
# 25%         18.500000
# 50%         30.500000
# 75%         42.800000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# жилая площадь в нашей выборке колеблется от 2 до 409,7 м2, среднее значение 30 кв.м, а медиана 34 кв.м. Аномальные значения более 180 кв.м

# %% [markdown]
# Рассмотрим 'kitchen_area'

# %%
data['kitchen_area'].hist(bins = 100, range=(0,100))
plt.show()

# %%
#получим характеристики по выборке методом describe()
 
data['kitchen_area'].describe()
# Out:
# count    23453.000000
# mean        10.461736
# std          5.661329
# min          1.300000
# 25%          7.300000
# 50%          9.040000
# 75%         11.500000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# площадь кухни в нашей выборке колеблется от 1,3 до 112 м2, среднее значение 9 кв.м, а медиана 10,6 кв.м. Аномальные значения более 50 кв.м

# %% [markdown]
# Рассмотрим 'rooms'

# %%
data['rooms'].hist(bins = 20, range=(0,20))
plt.show()

# %%
#получим характеристики по выборке методом describe()
 
data['rooms'].describe()
# Out:
# count    23453.000000
# mean         2.087494
# std          1.066253
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Количество комнат колеблется от 1 до 14, среднее значение 2, а медиана 2. Аномальные значения более 8

# %% [markdown]
# Рассмотрим 'floors_total'

# %%
data['floors_total'].hist(bins = 30, range=(0,70))
plt.show()

# %%
data['floors_total'].describe()
# Out:
# count    23453.000000
# mean        10.622223
# std          6.566513
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Количество этажей в доме колеблется от 1 до 60, среднее значение 9, а медиана 10,6. Аномальные значения более 30

# %% [markdown]
# Рассмотрим 'days_exposition'

# %%
data['days_exposition'].hist(bins = 100, range=(0,2000))
plt.show()

# %%
data['days_exposition'].describe()
# Out:
# count    23453.000000
# mean       156.911184
# std        213.927248
# min          0.000000
# 25%         22.000000
# 50%         74.000000
# 75%        199.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Количество дней публикации объявления колеблется от 0 до 1580, среднее значение 78, а медиана 159. Аномальные значения более 1000
# П.С. Вообще мне кажется аномальным, что есть обьявления о сдаче больше года...

# %% [markdown]
# Рассмотрим 'floor'

# %%
data['floor'].hist(bins = 50, range=(0,50))
plt.show()

# %%
data['floor'].describe()
# Out:
# count    23453.000000
# mean         5.870720
# std          4.863671
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %% [markdown]
# Значение в столбце "Этаж квартиры" колеблется от 1 до 27, среднее значение 4, а медиана 6. Аномальные значения более 25

# %%
#убираем аномальные значения в столбцах total_area,rooms,floors_total,living_area, kitchen_area, days_exposition
 
data = data.query('total_area<=300 and living_area<=180 and kitchen_area<=50 and rooms<=8 and floors_total<=30 and days_exposition<=1000 and floor<=25')

# %% [markdown]
# Рассмотрим 'ceiling_height'

# %%
data['ceiling_height'].hist(bins = 50, range=(0,8))
plt.show()

# %% [markdown]
# видно, что максимальное значение аномальное(высота потолка 100 м). также есть значения с высотой менее 2 м,что также кажется неккоректным. заполним аномальные значения (менее 2 м и более 5 м) медианой.

# %%
data.loc[(data['ceiling_height']<2) | (data['ceiling_height']>5), 'ceiling_height'] =data['ceiling_height'].median()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# тут согласен
# </div>

# %%
data['last_price'].describe()
# Out:
# count    2.300000e+04
# mean     6.201761e+06
# std      7.247347e+06
# min      1.219000e+04
# 25%      3.440000e+06
# 50%      4.600000e+06
# 75%      6.700000e+06
# max      3.300000e+08
# Name: last_price, dtype: float64

# %%
data['last_price'].sort_values(ascending=False)
# Out:
# 1436     330000000
# 22831    289238400
# 8900     190870000
# 19155    160000000
# 2536     159984000
#            ...
# 17676       450000
# 16274       440000
# 14911       430000
# 17456       430000
# 8793         12190
# Name: last_price, Length: 23000, dtype: int64

# %% [markdown]
# Сейчас бы купить квартиру за 12190 рублей...
# Значение явно аномально, скорее всего тут имелось в виду сдача квартиры в аренду или просто ошибка пользователя - уберем его из датасета

# %%
data = data.loc[data['last_price'] != 12190]

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Второй раздел сделан хорошо. Проверены основные возможные проблемы в данных.

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавим в таблицу новые столбцы со следующими параметрами: цена одного квадратного метра; день недели публикации объявления (0 — понедельник, 1 — вторник и так далее); месяц публикации объявления; год публикации объявления; тип этажа квартиры (значения — «первый», «последний», «другой»); расстояние до центра города в километрах

# %%
#цена одного квадратного метра,округлим значения до целого
 
data['price_square_meter'] = data['last_price']/data['total_area']

data = data.round({'price_square_meter': 0})

# %%
#день недели публикации
data['week_day'] = pd.DatetimeIndex(data['first_day_exposition']).day_name()

#месяц публикации объявления 
data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month_name()

# год публикации объявления
data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year

# %%
data['weeks_day_exposition'] = data['first_day_exposition'].dt.weekday

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
# </div>

# %%
# тип этажа квартиры (значения — «первый», «последний», «другой»)
 
def floor_type(floor):
 
    if floor['floor'] == 1:
 
        return 'Первый'
 
    elif floor['floor'] == floor['floors_total']:
 
        return 'Последний'
 
    else:
 
        return 'Другой'
data['floor_type'] = data.apply(floor_type, axis=1)

# %%
#расстояние до центра города в километрах (перевем из м в км и округлим до целых значений)
 
data['cityCenters_nearest_km'] = data['cityCenters_nearest'] / 1000

data = data.round({'cityCenters_nearest_km': 0})

# %% [markdown]
# Убедимся, что все работает

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70            16         51.0      8        False   False
# 1            2.40            11         18.6      1        False   False
# 2            2.40             5         34.3      4        False   False
# 3            2.40            14         45.0      9        False   False
# 4            3.03            14         32.0     13        False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Этот раздел выполнен качественно
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# Изучим следующие параметры объектов:
# общая площадь;
# жилая площадь;
# площадь кухни;
# цена объекта;
# количество комнат;
# высота потолков;
# этаж квартиры;
# тип этажа квартиры («первый», «последний», «другой»);
# общее количество этажей в доме;
# расстояние до центра города в метрах;
# расстояние до ближайшего аэропорта;
# расстояние до ближайшего парка;
# день и месяц публикации объявления.

# %%
data['total_area'].hist(bins = 100, range=(0,300))
plt.show()

# %%
data['total_area'].hist(bins = 100, range=(0,100))
plt.show()

# %% [markdown]
# Большая часть обьявлений о продаже квартир имеют общую площадь 40-45 м2

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Я бы советовал сократить range и тогда мы сможем увидеть пиковые значения.
# </div>

# %% [markdown]
# <div class="alert alert-info"> 🧩<b>Комментарии студента:</b>Сократил с 400 до 300 и сделал отдельно для 100. Там наиболее наглядно показаны пиковые значения.   </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличная визуализация
# </div>

# %%
data['living_area'].hist(bins = 100, range=(0,200))
plt.show()

# %%
data['living_area'].hist(bins = 100, range=(0,100))
plt.show()

# %% [markdown]
# Очень много обьявлений о продаже квартир имеют жилую площадь около 15 м2, также очень много в диапозоне около 30 м2

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Лучше после каждого графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи - так проще читать проект, поскольку будущим коллегам или заказчику не надо будет самим интерпретировать результаты каждого теста или графика.

# %% [markdown]
# <div class="alert alert-info"> 🧩<b>Комментарии студента:</b> добавил выводы к графикам, также добавил несколько уменьшенных по range графиков для наглядности пиковых значений.  </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Всё верно =)
# </div>

# %%
data['kitchen_area'].hist(bins = 100, range=(0,100))
plt.show()

# %%
data['kitchen_area'].hist(bins = 100, range=(0,40))
plt.show()

# %% [markdown]
# Большая часть выставленных на продажу квартир имеют площадь кухни от 5 до 10 м2
# Также стоит отметить, что чаще всего встречаются квартиры с кухней площадью 7 м2

# %%
data['last_price'].hist(bins = 50, range=(0,10000000))
plt.show()

# %% [markdown]
# Большая часть выставленных на продажу квартир стоят около 4 миллионов рублей

# %%
data['rooms'].hist(bins = 20, range=(0,10))
plt.show()

# %% [markdown]
# Большая часть выставленных на продажу квартир имеют 1-2 комнаты

# %%
data['ceiling_height'].hist(bins = 50, range=(2,6))
plt.show()

# %% [markdown]
# В большинстве квартир выставленных на продажу высота потолков 2.4 - 2.5 м

# %%
data['floor'].hist(bins = 50, range=(0,30))
plt.show()

# %% [markdown]
# Много квартир на 2 этаже, квартиры на 5 этаже и выше продают выставляют на продажу существенно реже

# %%
data['floor_type'].hist(bins = 50, range=(0,3))
plt.show()

# %% [markdown]
# Количество квартир на первом и последнем этаже существенно меньше

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Полученные данные соответствуют реалиям
# </div>

# %%
data['floors_total'].hist(bins = 30, range=(0,30))
plt.show()

# %% [markdown]
# преобладают обьявления о квартирах 5-ти этажных зданиях, также много обьявлений о продаже в 9-ти этажном здании

# %%
data['cityCenters_nearest_km'].hist(bins = 30, range=(0,60))
plt.show()

# %% [markdown]
# До ближайшего центра города как правило около 15 км

# %%
data['airports_nearest'].hist(bins = 30, range=(0,100000))
plt.show()

# %% [markdown]
# До ближайшего аэропорта как правило около от 15 до 25 км
# Квартиры находящиеся на расстоянии свыше 40 км продают реже

# %%
data['parks_nearest'].hist(bins = 30, range=(0,4000))
plt.show()

# %% [markdown]
# Большая часть квартир находится в 500 метрах от парков

# %%
data['week_day'].hist(bins = 50, range=(0,7))
plt.show()

# %% [markdown]
# Наиболее часто выставляют квартиры на продажу во вторник

# %%
data['month'].hist(bins = 50, range=(0,12))
plt.show()

# %% [markdown]
# Большая часть квартир выставлена на продажу в марте

# %% [markdown]
# Получим описание всех исследуемых данных

# %%
 
data[['total_area','living_area','kitchen_area','last_price','rooms','ceiling_height','floor','floor_type','floors_total','cityCenters_nearest_km','airports_nearest','parks_nearest','week_day','month']].describe()
# Out:
#          total_area   living_area  kitchen_area    last_price         rooms  \
# count  22999.000000  22999.000000  22999.000000  2.299900e+04  22999.000000
# mean      59.127222     33.717946     10.269553  6.202031e+06      2.064394
# std       29.249872     18.812300      4.907030  7.247390e+06      1.007098
# min       12.000000      2.000000      1.300000  4.300000e+05      1.000000
# 25%       40.000000     18.420000      7.200000  3.440000e+06      1.000000
# 50%       52.000000     30.300000      9.040000  4.600000e+06      2.000000
# 75%       69.000000     42.400000     11.400000  6.700000e+06      3.000000
# max      300.000000    180.000000     50.000000  3.300000e+08      8.000000
#
#        ceiling_height         floor  floors_total  cityCenters_nearest_km  \
# count    22999.000000  22999.000000  22999.000000            17622.000000
# mean         2.595949      5.836689     10.589460               14.245318
# ...

# %% [markdown]
# В данной таблице указаны основные характеристики квартир.
#
# Можем сделать вывод, что среднестатистическая квартира на продажу (по медианным значениям) имеет общую площадь в районе 60 м2, причем на жилую площадь обычно идет более 33 м2, а кухня в райне 10 м2, высота потолка в среднем 2,6 м. Как правило в такой квартире 2 комнаты и находится она на 6 этаже 10 этажного здания.
# Стоимость такой квартиры в районе 6 миллионов рублей

# %% [markdown]
# Посмотрим, как быстро продавались квартиры
# Т.к. как на этапе предобработки мы заменяли пропущенные значения на 0, для более точной выборки уберем выставленные публикации со сроком публикации 0 дней

# %%
data_for_days_exposition = data  
data_for_days_exposition = data.loc[data['days_exposition'] != 0]

# %%
data_for_days_exposition['days_exposition'].hist(bins = 50, range=(0,1000))
plt.show()

# %%
data_for_days_exposition['days_exposition'].hist(bins = 50, range=(0,500))
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Давай тут уменьшим range, возможно тут есть интересные аномалии
# </div>

# %%
data_for_days_exposition['days_exposition'].hist(bins = 50, range=(0,200))
plt.show()

# %% [markdown]
# Очень много квартир стоят на продаже примерно 45 дней

# %% [markdown]
# <div class="alert alert-info"> 🧩<b>Комментарии студента:</b> Интересно с чем это связано? </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Наблюдаем пики на 45 и 60 дни, это очень похоже на техническую особенность самой платформы. Вероятнее всего, в эти дни платформа удаляет объявления, если пользователь не продлил его
# </div>

# %%
 data_for_days_exposition['days_exposition'].describe()
# Out:
# count    19867.000000
# mean       167.393517
# std        187.435833
# min          1.000000
# 25%         44.000000
# 50%         93.000000
# 75%        221.500000
# max       1000.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# В среднем квартиры продаются примерно за 187 дней, хотя есть и такие, что покупают в первые же дни выставления на продажу и те, что "висят" 1000 дней.
# Можно сделать выводы, что половина квартир продается в течении полугода. Быстрой же можно считать продажу, укладывающуюся по времени в 3 месяца. Долгой, в свою очередь, будет продажа квартиры более года.

# %% [markdown]
# Рассмотрим какие факторы больше всего влияют на общую (полную) стоимость объекта

# %%
data.plot(x='total_area', y='last_price', 
               kind='scatter', alpha=0.08, 
               xlim=(0, 150), ylim=(0, 13000000), 
               figsize=(16, 9))
plt.show()

# %%
data['last_price'].corr(data['total_area'])
# Out:
# 0.6766419128109809

# %% [markdown]
# Чем больше площадь квартиры, тем больше ее цена.

# %%
data.plot(x='living_area', y='last_price', 
               kind='scatter', alpha=0.08, 
               xlim=(0, 150), ylim=(0, 13000000), 
               figsize=(16, 9))
plt.show()

# %%
data['last_price'].corr(data['living_area'])
# Out:
# 0.5686201687594455

# %% [markdown]
# Чем больше жилая площадь квартиры, тем больше ее цена.

# %%
data.plot(x='kitchen_area', y='last_price', 
               kind='scatter', alpha=0.08, 
               xlim=(0, 150), ylim=(0, 13000000), 
               figsize=(16, 9))
plt.show()

# %%
data['last_price'].corr(data['kitchen_area'])
# Out:
# 0.4780533310138338

# %% [markdown]
# А вот с площадью кухни наоборот
# Квартиры с большой кухней стоят немного дешевле

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верная интерпретация значений корреляции Пирсона
# </div>

# %%
data.pivot_table(index='floor', values='last_price', aggfunc='median').plot(style='o-', title='Зависимость цены от этажа')
plt.show()

# %% [markdown]
# Цена в зависимости от этажа слишком сильно варьируется, но все же можно предположить, что люди предпочитаю жить на более высоких этажах

# %% [markdown]
# Попробуем разобраться так ли это при помощи корреляции Пирсона

# %%
data.plot(x='floor', y='last_price', 
               kind='scatter', alpha=0.08, 
               xlim=(0, 25), ylim=(0, 13000000), 
               figsize=(16, 9))
plt.show()

# %%
data['last_price'].corr(data['floor'])
# Out:
# 0.039296544708233086

# %% [markdown]
# Если коэффициент корреляции равен 0 то, это говорит об отсутствии корреляционных связей между переменными
# Здесь мы видим крайне малое число коэффициента корреляции, что говорит, что прямой зависимости между ценой и этажом - нет

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Давай к каждому графику в этом шаге добавим значение корреляции и интерпретируем полученные данные?
# </div>

# %% [markdown]
# <div class="alert alert-info"> 🧩<b>Комментарии студента:</b> Если смотреть по коррелиции зависимости от этажа и стоимости практически нет </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Согласен.
# </div>

# %%
data.pivot_table(index='floor_type', values='last_price').plot(style='o-', title='Зависимость цены от этажа')
plt.show()

# %% [markdown]
# Квартиры на 1 этаже дешевле

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Как в песне, "первый и последний этаж не предлагать". Традиционно, квартиры на первом и последнем этажах считаются самыми неудобными для жизни и это отражается на их стоимости.
# </div>

# %%
data['last_price'].describe()
# Out:
# count    2.299900e+04
# mean     6.202031e+06
# std      7.247390e+06
# min      4.300000e+05
# 25%      3.440000e+06
# 50%      4.600000e+06
# 75%      6.700000e+06
# max      3.300000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Существуют квартиры которые стоят миллиарды, но как мы ранее выяснили по гистограммам немного, поэтому ограничимся ценой в 10 000 000 рублей, что немного превышает 75%

# %%
data_for_price = data
data_for_price = data.loc[data['last_price'] <= 10000000]

# %%
for column in ['week_day', 'month', 'year']:
    seaborn.catplot(x=column, y="last_price",height=10, kind="box", data=data_for_price, palette='Set3');

# %% [markdown]
# Стоимость квартиры практически не зависит от дня выкладывания обьявления
# Самые дорогие квартиры выкладывают в основном в апреле, самые дешевые в июле
# Обьявления 2014 года включают в себя самые дорогие квартиры, с 2015 года пошел спад стоимости жилья, с 2016 по 2018 стоимость почти не менялась, в 2019 замечен рост цен на квартиры

# %%
for column in ['week_day', 'month', 'year']:
    seaborn.catplot(x=column, y="total_area",height=10, kind="box", data=data_for_price, palette='Set3');

# %% [markdown]
# Рассмотрим также влияние площади квартир по времени обьявления о продаже

# %% [markdown]
# Стоимость квартиры по прежнему практически не зависит от дня выкладывания обьявления
# Самые большие квартиры выложены в основном в ноябре, но в целом по месяцам нет большой разницы
# Обьявления 2014 года включают в себя самые дорогие квартиры, но при этом еще и самые большие по площади, с 2015 года пошел спад стоимости жилья, но и сами квартиры в этом году выставлены с меньшей площадью, с 2016 по 2019 стоимость почти не менялась.
# В 2019 году нет резко скачка в размере жилья, что действительно говорит, что в 2019 году стоимость жилья стала больше

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Давай рассмотрим динамику цены 1м2 и площади продаваемых квартир. И потом пересмотрим выводы, т.к., возможно, упала не столько цена, сколько площадь продаваемых квартир?
# </div>

# %% [markdown]
# <div class="alert alert-info"> 🧩<b>Комментарии студента:</b> Добавил, и правда есть зависимость, но с 2019 года стоимость жилья действительно стала больше </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличный инсайд для заказчика. Ты молодец =)
# </div>

# %% [markdown]
# Рассмотрим в каких городах близ Санкт-Петербурга самая большая цена за квадратный метр жилья

# %%
top_10 = data.pivot_table(index="locality_name", values ="price_square_meter", aggfunc=["mean","count"])
top_10.columns = ["mean","count"]

top_10 = top_10.sort_values("count",ascending=False).head(10)
top_10 = top_10.reset_index()
print(top_10)
# Out:
#        locality_name           mean  count
# 0    Санкт-Петербург  113783.726951  15261
# 1     поселок Мурино   85190.900585    513
# 2     поселок Шушары   78341.111111    432
# 3         Всеволожск   68663.853093    388
# 4             Пушкин  103030.098039    357
# 5            Колпино   75279.704478    335
# 6  поселок Парголово   90005.616883    308
# 7            Гатчина   68746.110749    307
# 8    деревня Кудрово   92239.075540    278
# 9             Выборг   58121.275424    236

# %% [markdown]
# Самым дорогим городом является Санкт-Петербург
# замыкает топ 10 самых дорогих городов Выборг

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Таблица верна. Совет: на общие продажи лучше смотреть через призму медианы. Она более устойчива к выбросам
# </div>

# %% [markdown]
# Рассмотрим зависимость цены на квадратный метр жилья в Санкт-Петербурге от расстояния до центра города

# %%
center_spb_data = data.query('locality_name == "Санкт-Петербург"')

# %%
center_spb_data.plot(kind = 'scatter', y = 'price_square_meter', x = 'cityCenters_nearest', alpha=0.08, xlim=(0, 30000), ylim=(0,1000000), figsize=(16, 9))

center_spb_data['cityCenters_nearest'].corr(center_spb_data['price_square_meter'])
# Out:
# -0.3229924272996609

# %% [markdown]
# Наибольшая цена в пределах 10000 - 17000 км
# Есть дорогие квартиры в центре, но все же большинство из них стоят меньше чем в вышеуказанных пределах расстояния
# на на окраинах стоимость меньше

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Неплохо бы добавить линейный график и посмотреть распределение цены от расстояния
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Целью проекта было проведение анализа данных для определения зависимости цен на недвижимость в Санкт-Петербурге и соседних населённых пунктах за несколько лет.
#
# Результатом предобработки данных стало:
# Обработка пропущенных значений, заполнение возможных пропусков, таких как класификация жилья как апартаменты, наличие поблизости парков, прудов и аэропортов, а также расстояние до них, также было заполнено наличие балконов, высота потолков, расстояние до городского центра, общей площади жилья, жилой зоны и кухни.  Были устранены дубликаты в названии городов.  Также были обработаны выбивающиеся значения всех показателей.
# Были изменены типы данных для проведения анализа. С целью дальнейшего исследования было посчитаны и добавлены в таблицу следующие показатели: цена квадратного метра жилья, отдельные показатели даты – дни недели, месяцы и года размещения объявлений, категории по этажам квартир.
# В данном проекте были проанализированы данные для определения зависимости цен на недвижимость в Санкт-Петербурге и области от разных факторов.
#
# По итогам исследования можно сделать следующие выводы:
# 1. цена на квартиру прежде всего зависит от:
#
# - общей площади;
# - количества комнат;
# - удаленности от центра;
# - этажа (первый, последний, или другой);
#
# 2. Практически не зависит цена от дня недели и месяца публикации внутри года. Однако в разные годы цены меняются в зависимости от общих экономических трендов. В 2019 году произошел рост цен на недвижимость.
# 3. На стоимость квадратного метра квартиры больше всего влияют количество комнат, этаж квартиры, близость к центру.
# 4. Примерно половина квартир продается в течении полугода. Быстрой же можно считать продажу, укладывающуюся по времени в 3 месяца. Долгой, в свою очередь, будет продажа квартиры более года.
# 5. В Санкт-Петербурге наибольшая цена на квартиры в пределах 10000 - 17000 км от центра. Есть дорогие квартиры в самом центре города, но все же большинство из них стоят меньше чем в вышеуказанных пределах расстояния.
# 6. Самым дорогим городом является Санкт-Петербург замыкает топ 10 самых дорогих городов Выборг.
# 7. Результаты каждого проведенного исследования представлены в виде графиков.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# __Комментарий от ревьюера №1__
#
# Давай немного увеличим объем вывода, он получился скудным. Хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно.
#
# ---
#
# Так же после исследования, бизнесу нужны будут рекомендации.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Шикарный вывод. Чётко и лакончино
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Интерпретировать полученные данные сразу после построения графиков или таблиц
#
# 2) Уменьшить range, чтобы рассмотреть пики
#
# 3) Значения корреляции
#
# 4) Финальный вывод
#
# 5) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
